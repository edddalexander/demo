# %%
import requests
import time
from datetime import datetime, timedelta


api_key = 'CG-aL2S95XK2JiuXLRZPX9wx2rC'
#base_url = "https://api.coingecko.com/api/v3/coins/"
headers = {'X-Cg-Apikey': api_key}
coin_id= 'ethereum'
# "https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&ids=bitcoin"
# f"https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&ids={coin_id}"

# %%
date = '03-07-2024' #datetime(year=2021, month=10, day=1).strftime('%Y-%m-%d')

url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart/range?vs_currency=usd&from=1633046400&to=1633132800&interval=daily"

headers = {
    "accept": "application/json",
    "X-Cg-Apikey": api_key
}
params = {  
        'ids': 'ethereum',
        'vs_currencies': 'USD',
        'include_24hr_vol': 'true',
        'date':  date
        
}

response = requests.get(url, headers=headers, params=params)
data = response.json()
print(response.text)
# Out:
# {"status":{"timestamp":"2024-07-07T09:54:06.377+00:00","error_code":10005,"error_message":"interval=daily is exclusive to paid plan subscribers only, please visit: https://www.coingecko.com/en/api/pricing. Tips: you can retrieve daily interval data automatically, as long as the date range is longer than 90 days; you don't have to specify the interval parameter which is optional."}}

# %%
url = 'https://api.coingecko.com/api/v3/coins/bitcoin/simple/price?include_24hr_vol=true'

# %%
response = requests.get(url,headers=headers)
print(response.text)
# Check for successful response
'''if response.status_code == 200:
  # Access the response data as JSON (assuming JSON format)
  data = response.json()

  # Open the CSV file for writing
  with open("data.csv", 'w', newline='') as csvfile:
    # Create a CSV writer object
    writer = csv.writer(csvfile) '''
# Out:
# {"error":"Incorrect path. Please check https://www.coingecko.com/api/"}
# 'if response.status_code == 200:\n  # Access the response data as JSON (assuming JSON format)\n  data = response.json()\n\n  # Open the CSV file for writing\n  with open("data.csv", \'w\', newline=\'\') as csvfile:\n    # Create a CSV writer object\n    writer = csv.writer(csvfile) '

# %%
coinmarket_key = '4cd46783-7c2c-4d25-96bc-b1793a2e899e'
url =  'https://pro-api.coinmarketcap.com/v2/cryptocurrency/quotes/historical'


headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': coinmarket_key,
}
parameters = {
  'id': '1',
  'convert': 'USD',
  'time_start': '2024-06-07',
  'time_end': '2024-07-07',
  'interval': 'daily',
  'count': '1',
}

response = requests.get(url, headers=headers, params=parameters)
data = response.json()
print(data)
# Out:
# {'status': {'timestamp': '2024-07-07T11:25:59.484Z', 'error_code': 0, 'error_message': None, 'elapsed': 68, 'credit_count': 1, 'notice': None}, 'data': {'quotes': [{'timestamp': '2024-06-08T00:00:00.000Z', 'quote': {'USD': {'percent_change_1h': -0.201370110861, 'percent_change_24h': -2.046329401051, 'percent_change_7d': 2.739879291069, 'percent_change_30d': 13.328114828191, 'price': 69324.17654684478, 'volume_24h': 36194100670.65, 'market_cap': 1366323783100.367, 'total_supply': 19709196, 'circulating_supply': 19709196, 'timestamp': '2024-06-08T00:00:00.000Z'}}}, {'timestamp': '2024-06-09T00:00:00.000Z', 'quote': {'USD': {'percent_change_1h': -0.046862939719, 'percent_change_24h': -0.038488347552, 'percent_change_7d': 2.339878795479, 'percent_change_30d': 9.887883861734, 'price': 69297.49481683817, 'volume_24h': 14260551225.99, 'market_cap': 1365834288838.8264, 'total_supply': 19709721, 'circulating_supply': 19709721, 'timestamp': '2024-06-09T00:00:00.000Z'}}}, {'timestamp': '2024-06
# ...

# %%
#coinbase
api_key = 'organizations/c44ddd82-455c-46ed-921c-192b93610529/apiKeys/e78c3c54-cf27-4bee-8ca4-00bdb786ac46'
# Out:
#   File "/var/folders/82/5nmvsb8x09b6kl66qrrrhl5508pplg/T/ipykernel_34918/2693010783.py", line 23
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
# Out:
# Error fetching data for bitcoin on 2023-07-07: 404
# Error fetching data for bitcoin on 2023-07-08: 404
# Error fetching data for bitcoin on 2023-07-09: 404
# Error fetching data for bitcoin on 2023-07-10: 404
# Error fetching data for bitcoin on 2023-07-11: 404
# Error fetching data for bitcoin on 2023-07-12: 429
# Error fetching data for bitcoin on 2023-07-13: 429
# Error fetching data for bitcoin on 2023-07-14: 429
# Error fetching data for bitcoin on 2023-07-15: 429
# Error fetching data for bitcoin on 2023-07-16: 429
# Error fetching data for bitcoin on 2023-07-17: 429
# Error fetching data for bitcoin on 2023-07-18: 429
# Error fetching data for bitcoin on 2023-07-19: 429
# Error fetching data for bitcoin on 2023-07-20: 429
# Error fetching data for bitcoin on 2023-07-21: 429
# Error fetching data for bitcoin on 2023-07-22: 429
# Error fetching data for bitcoin on 2023-07-23: 429
# Error fetching data for bitcoin on 2023-07-24: 429
# ...
